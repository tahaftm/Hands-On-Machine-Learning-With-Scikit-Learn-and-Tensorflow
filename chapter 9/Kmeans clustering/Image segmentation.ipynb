# %% [markdown]
# # Image Segmentation

# %%
from matplotlib.image import imread

# %%
import os
image = imread(os.path.join("ladybug.jpg"))
image.shape
# Out:
# (168, 300, 3)

# %%
image
# Out:
# array([[[108, 193,  30],
#         [109, 194,  31],
#         [112, 194,  34],
#         ...,
#         [107, 197,  21],
#         [107, 197,  21],
#         [107, 197,  21]],
#
#        [[110, 194,  38],
#         [111, 195,  39],
#         [114, 195,  41],
#         ...,
#         [106, 197,  16],
#         [106, 197,  16],
#         [106, 197,  16]],
#
#        [[114, 196,  49],
#         [114, 196,  49],
#         [117, 196,  51],
#         ...,
#         [105, 197,  10],
#         [105, 197,  10],
#         [105, 197,  10]],
#
#        ...,
#
#        [[ 94, 200,  38],
#         [ 85, 192,  26],
#         [ 75, 181,  10],
#         ...,
#         [ 16,  90,   1],
#         [ 19,  94,   3],
#         [ 22,  97,   6]],
#
#        [[ 81, 191,  32],
#         [ 77, 185,  21],
#         [ 71, 179,   7],
#         ...,
#         [ 16,  90,   1],
#         [ 20,  95,   4],
#         [ 23,  98,   7]],
#
#        [[ 63, 173,  16],
#         [ 63, 174,  10],
#         [ 68, 178,   5],
#         ...,
#         [ 16,  90,   1],
#         [ 20,  95,   4],
#         [ 23,  98,   7]]], shape=(168, 300, 3), dtype=uint8)

# %%
X = image.reshape(-1,3)
X
# Out:
# array([[108, 193,  30],
#        [109, 194,  31],
#        [112, 194,  34],
#        ...,
#        [ 16,  90,   1],
#        [ 20,  95,   4],
#        [ 23,  98,   7]], shape=(50400, 3), dtype=uint8)

# %%
import matplotlib.pyplot as plt

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')


ax.scatter(X[:, 0], X[:, 1], X[:, 2])

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X)
plt.scatter(X_pca[:,0], X_pca[:,1])

# %%
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=8).fit(X)
segmented_img = kmeans.cluster_centers_[kmeans.labels_]
segmented_img = segmented_img.reshape(image.shape)

# %%
segmented_img
# Out:
# array([[[114.62826347, 196.07904192,  45.77796407],
#         [114.62826347, 196.07904192,  45.77796407],
#         [114.62826347, 196.07904192,  45.77796407],
#         ...,
#         [114.62826347, 196.07904192,  45.77796407],
#         [114.62826347, 196.07904192,  45.77796407],
#         [114.62826347, 196.07904192,  45.77796407]],
#
#        [[114.62826347, 196.07904192,  45.77796407],
#         [114.62826347, 196.07904192,  45.77796407],
#         [114.62826347, 196.07904192,  45.77796407],
#         ...,
#         [ 89.88751793, 182.0695122 ,   4.8374462 ],
#         [ 89.88751793, 182.0695122 ,   4.8374462 ],
#         [ 89.88751793, 182.0695122 ,   4.8374462 ]],
#
#        [[114.62826347, 196.07904192,  45.77796407],
#         [114.62826347, 196.07904192,  45.77796407],
#         [114.62826347, 196.07904192,  45.77796407],
#         ...,
#         [ 89.88751793, 182.0695122 ,   4.8374462 ],
#         [ 89.88751793, 182.0695122 ,   4.8374462 ],
#         [ 89.88751793, 182.0695122 ,   4.8374462 ]],
#
#        ...,
#
#        [[114.62826347, 196.07904192,  45.77796407],
#         [ 89.88751793, 182.0695122 ,   4.8374462 ],
#         [ 89.88751793, 182.0695122 ,   4.8374462 ],
#         ...,
#         [ 25.49685078, 123.78330911,   3.49152132],
#         [ 25.49685078, 123.78330911,   3.49152132],
#         [ 25.49685078, 123.78330911,   3.49152132]],
#
#        [[ 89.88751793, 182.0695122 ,   4.8374462 ],
#         [ 89.88751793, 182.0695122 ,   4.8374462 ],
#         [ 89.88751793, 182.0695122 ,   4.8374462 ],
#         ...,
#         [ 25.49685078, 123.78330911,   3.49152132],
#         [ 25.49685078, 123.78330911,   3.49152132],
#         [ 25.49685078, 123.78330911,   3.49152132]],
#
#        [[ 62.2300288 , 161.27292709,   3.93550099],
#         [ 62.2300288 , 161.27292709,   3.93550099],
#         [ 62.2300288 , 161.27292709,   3.93550099],
#         ...,
#         [ 25.49685078, 123.78330911,   3.49152132],
#         [ 25.49685078, 123.78330911,   3.49152132],
#         [ 25.49685078, 123.78330911,   3.49152132]]], shape=(168, 300, 3))
