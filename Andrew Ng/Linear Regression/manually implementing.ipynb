# %%
import numpy as np

# %%
X_train = np.array([1.0, 2.0])
y_train = np.array([300.0, 500.0])
print(f"x_train = {x_train}")
print(f"y_train = {y_train}")
# Out:
# x_train = [1. 2.]
# y_train = [300. 500.]

# %%
## number of training examples: 
m = X_train.shape[0]

# %%
## Visulaizing the data
import matplotlib.pyplot as plt
plt.scatter(X_train, y_train, marker = 'x', c = 'r')
plt.xlabel('3 of bedrooms')
plt.ylabel('Price')
plt.title('Housing Prices')
# Out:
# Text(0.5, 1.0, 'Housing Prices')

# %%
w = 100
b = 100

# %%
def compute(X_train, w, b):
    f_wb = np.zeros(m)
    for i in range(m):
        f_wb[i] = w * X_train[i] + b 
    return f_wb

# %%
compute(X_train,w, b)
# Out:
# array([200., 300.])

# %%
## Visulaizing the data
import matplotlib.pyplot as plt
plt.scatter(X_train, y_train, marker = 'x', c = 'r')
plt.plot(X_train, compute(X_train, w, b), c = 'b')
plt.xlabel('3 of bedrooms')
plt.ylabel('Price')
plt.title('Housing Prices')
# Out:
# Text(0.5, 1.0, 'Housing Prices')

# %% [markdown]
# Computing the cost
#
# ![image.png](attachment:image.png)

# %%
def cost(X,y,w,b):
    cost_sum = 0
    for i in range(m):
        cost_sum +=  (compute(X, w, b)[i] - y[i])**2
    return cost_sum / (2 * m)

# %%
cost(X_train, y_train, w, b)
# Out:
# np.float64(12500.0)
